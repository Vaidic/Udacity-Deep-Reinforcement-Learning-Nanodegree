# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='./Reacher_Windows_x86_64/Reacher.exe')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726671e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
# env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
# states = env_info.vector_observations                  # get the current state (for each agent)
# scores = np.zeros(num_agents)                          # initialize the score (for each agent)
# while True:
#     actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#     actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#     env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#     next_states = env_info.vector_observations         # get next state (for each agent)
#     rewards = env_info.rewards                         # get reward (for each agent)
#     dones = env_info.local_done                        # see if episode finished
#     scores += env_info.rewards                         # update the score (for each agent)
#     states = next_states                               # roll over states to next time step
#     if np.any(dones):                                  # exit loop if episode finished
#         break
# print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
# env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %% [markdown]
# ### Agent Training (Using DDPG)

# %%
from ddpg_agent import Agent
from collections import namedtuple, deque
import torch
import matplotlib.pyplot as plt

# %%
env_info = env.reset(train_mode=True)[brain_name]
agent = Agent(env_info.vector_observations.shape[1], brain.vector_action_space_size, random_seed=2019)

# %%
def ddpg(n_episodes=400, max_t=500):
    avg_score = []
    chkpt_episodes = 50
    scores_deque = deque(maxlen=100)
    scores = np.zeros(num_agents)
    time_steps = 20
    num_update = 10
    len_agents = len(str(num_agents))
    
    env_solv = False
    env_info = env.reset(train_mode=True)[brain_name]
    
    states = env_info.vector_observations
    
    agent_kwargs = {"state_size": state_size, "action_size": action_size, "random_seed": 2019}
    agents = [Agent(**agent_kwargs) for _ in range(num_agents)]
    assert len(agents) == num_agents
    action = [agent.act(states[idx]) for idx, agent in enumerate(agents)]

    
    
    for i_episode in range(1, n_episodes+1):
        states = env_info.vector_observations                  # get the current state (for each agent)
        for agent in agents:
            agent.reset()

        for t in range(max_t):
            actions = [agent.act(states[idx]) for idx, agent in enumerate(agents)]
            
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            
            step_tuple = zip(agents, states, actions, rewards, next_states, dones)
            
            for agent, s, a, r, s_, d in step_tuple:
                agent.memory.add(s, a, r, s_, d)
                if ( t % time_steps == 0):
                    agent.step(s,a, r, s_, d)
            states  = next_states
            scores += rewards                                  # update the score (for each agent)
            if np.any(dones):                                  # exit loop if episode finished
                break
                
        score = np.mean(scores)        
        avg_score.append(score)
        scores_deque.append(score)

        avg = np.mean(scores_deque)
            
            
        print('\rEpisode {}\tAverage Score: {:.2f}\tScore: {:.2f} \tMax Score: {:.2f}'.format(i_episode, avg, score, np.max(scores_deque)), end="\n")

        if not env_solv and np.mean(scores_deque) > 30.:
            print("\r\renv __solved__ @ i_episode={i_episode}, w/ avg_score={avg:.2f}\r".format(i_episode=i_episode, avg=avg))
            env_solv = True
        
        
        if i_episode % chkpt_episodes == 0:
            print("\repisodes: {i_episode}\tavg: {avg:.2f}".format(i_episode=i_episode, avg=avg))

            for idx, agent in enumerate(agents):
                chkpt_path_actor = "actor_" + str(idx).zfill(len_agents) + ".pth"
                torch.save(agent.actor_local.state_dict(), chkpt_path_actor)

                chkpt_path_critic = "critic_" + str(idx).zfill(len_agents) + ".pth"
                torch.save(agent.critic_local.state_dict(), chkpt_path_critic)

    return avg_score

# %%
scores = ddpg()
# Out:
# c:\users\vaidicj\anaconda3\envs\drl\lib\site-packages\torch\nn\functional.py:1320: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode 1	Average Score: 0.00	Score: 0.00 	Max Score: 0.00
# Episode 2	Average Score: 0.00	Score: 0.00 	Max Score: 0.00
# Episode 3	Average Score: 0.00	Score: 0.00 	Max Score: 0.00
# Episode 4	Average Score: 0.00	Score: 0.00 	Max Score: 0.00
# Episode 5	Average Score: 0.00	Score: 0.00 	Max Score: 0.00
# Episode 6	Average Score: 0.00	Score: 0.00 	Max Score: 0.00
# Episode 7	Average Score: 0.00	Score: 0.00 	Max Score: 0.00
# Episode 8	Average Score: 0.00	Score: 0.00 	Max Score: 0.00
# Episode 9	Average Score: 0.00	Score: 0.00 	Max Score: 0.00
# Episode 10	Average Score: 0.03	Score: 0.30 	Max Score: 0.30
# Episode 11	Average Score: 0.05	Score: 0.30 	Max Score: 0.30
# Episode 12	Average Score: 0.07	Score: 0.30 	Max Score: 0.30
# Episode 13	Average Score: 0.12	Score: 0.72 	Max Score: 0.72
# Episode 14	Average Score: 0.21	Score: 1.39 	Max Score: 1.39
# Episode 15	Average Score: 0.29	Score: 1.39 	Max Score: 1.39
# Episode 16	Average Score: 0.41	Score: 2.09 	Max Score: 2.09
# Episode 17	Average Score: 0.52	Score: 2.37 	Max Score: 2.37
# Episode 18	Average Score: 0.62	Score: 2.37 	Max Score: 2.37
# Episode 19	Average Score: 0.73	Score: 2.71 	Max Score: 2.71
# Episode 20	Average Score: 0.83	Score: 2.71 	Max Score: 2.71
# Episode 21	Average Score: 0.92	Score: 2.71 	Max Score: 2.71
# Episode 22	Average Score: 1.02	Score: 3.13 	Max Score: 3.13
# Episode 23	Average Score: 1.13	Score: 3.40 	Max Score: 3.40
# Episode 24	Average Score: 1.22	Score: 3.40 	Max Score: 3.40
# Episode 25	Average Score: 1.31	Score: 3.40 	Max Score: 3.40
# Episode 26	Average Score: 1.40	Score: 3.72 	Max Score: 3.72
# Episode 27	Average Score: 1.49	Score: 3.72 	Max Score: 3.72
# Episode 28	Average Score: 1.57	Score: 3.72 	Max Score: 3.72
# Episode 29	Average Score: 1.64	Score: 3.72 	Max Score: 3.72
# Episode 30	Average Score: 1.71	Score: 3.72 	Max Score: 3.72
# Episode 31	Average Score: 1.78	Score: 4.00 	Max Score: 4.00
# Episode 32	Average Score: 1.86	Score: 4.23 	Max Score: 4.23
# Episode 33	Average Score: 1.93	Score: 4.23 	Max Score: 4.23
# Episode 34	Average Score: 2.00	Score: 4.23 	Max Score: 4.23
# Episode 35	Average Score: 2.07	Score: 4.44 	Max Score: 4.44
# Episode 36	Average Score: 2.13	Score: 4.44 	Max Score: 4.44
# Episode 37	Average Score: 2.20	Score: 4.44 	Max Score: 4.44
# Episode 38	Average Score: 2.26	Score: 4.44 	Max Score: 4.44
# Episode 39	Average Score: 2.31	Score: 4.44 	Max Score: 4.44
# Episode 40	Average Score: 2.37	Score: 4.44 	Max Score: 4.44
# Episode 41	Average Score: 2.42	Score: 4.44 	Max Score: 4.44
# Episode 42	Average Score: 2.46	Score: 4.44 	Max Score: 4.44
# Episode 43	Average Score: 2.51	Score: 4.54 	Max Score: 4.54
# Episode 44	Average Score: 2.56	Score: 4.54 	Max Score: 4.54
# Episode 45	Average Score: 2.60	Score: 4.54 	Max Score: 4.54
# Episode 46	Average Score: 2.65	Score: 4.69 	Max Score: 4.69
# Episode 47	Average Score: 2.69	Score: 4.69 	Max Score: 4.69
# Episode 48	Average Score: 2.73	Score: 4.69 	Max Score: 4.69
# Episode 49	Average Score: 2.77	Score: 4.69 	Max Score: 4.69
# Episode 50	Average Score: 2.81	Score: 4.69 	Max Score: 4.69
# episodes: 50	avg: 2.81
# Episode 51	Average Score: 2.85	Score: 4.69 	Max Score: 4.69
# Episode 52	Average Score: 2.88	Score: 4.69 	Max Score: 4.69
# Episode 53	Average Score: 2.92	Score: 4.69 	Max Score: 4.69
# Episode 54	Average Score: 2.95	Score: 4.69 	Max Score: 4.69
# Episode 55	Average Score: 2.98	Score: 4.69 	Max Score: 4.69
# Episode 56	Average Score: 3.01	Score: 4.69 	Max Score: 4.69
# Episode 57	Average Score: 3.04	Score: 4.69 	Max Score: 4.69
# Episode 58	Average Score: 3.07	Score: 4.69 	Max Score: 4.69
# Episode 59	Average Score: 3.10	Score: 4.69 	Max Score: 4.69
# Episode 60	Average Score: 3.12	Score: 4.69 	Max Score: 4.69
# Episode 61	Average Score: 3.15	Score: 4.69 	Max Score: 4.69
# Episode 62	Average Score: 3.17	Score: 4.69 	Max Score: 4.69
# Episode 63	Average Score: 3.20	Score: 4.69 	Max Score: 4.69
# Episode 64	Average Score: 3.22	Score: 4.69 	Max Score: 4.69
# Episode 65	Average Score: 3.24	Score: 4.69 	Max Score: 4.69
# Episode 66	Average Score: 3.27	Score: 4.69 	Max Score: 4.69
# Episode 67	Average Score: 3.29	Score: 4.80 	Max Score: 4.80
# Episode 68	Average Score: 3.31	Score: 4.80 	Max Score: 4.80
# Episode 69	Average Score: 3.33	Score: 4.80 	Max Score: 4.80
# Episode 70	Average Score: 3.35	Score: 4.80 	Max Score: 4.80
# Episode 71	Average Score: 3.37	Score: 4.80 	Max Score: 4.80
# Episode 72	Average Score: 3.39	Score: 4.80 	Max Score: 4.80
# Episode 73	Average Score: 3.41	Score: 4.80 	Max Score: 4.80
# Episode 74	Average Score: 3.43	Score: 4.80 	Max Score: 4.80
# Episode 75	Average Score: 3.45	Score: 4.80 	Max Score: 4.80
# Episode 76	Average Score: 3.47	Score: 4.80 	Max Score: 4.80
# Episode 77	Average Score: 3.49	Score: 4.80 	Max Score: 4.80
# Episode 78	Average Score: 3.50	Score: 4.80 	Max Score: 4.80
# Episode 79	Average Score: 3.52	Score: 4.80 	Max Score: 4.80
# Episode 80	Average Score: 3.54	Score: 4.80 	Max Score: 4.80
# Episode 81	Average Score: 3.55	Score: 4.80 	Max Score: 4.80
# Episode 82	Average Score: 3.57	Score: 4.80 	Max Score: 4.80
# Episode 83	Average Score: 3.58	Score: 4.80 	Max Score: 4.80
# Episode 84	Average Score: 3.60	Score: 4.80 	Max Score: 4.80
# Episode 85	Average Score: 3.61	Score: 4.80 	Max Score: 4.80
# Episode 86	Average Score: 3.62	Score: 4.80 	Max Score: 4.80
# Episode 87	Average Score: 3.64	Score: 4.80 	Max Score: 4.80
# Episode 88	Average Score: 3.65	Score: 5.16 	Max Score: 5.16
# Episode 89	Average Score: 3.68	Score: 6.06 	Max Score: 6.06
# Episode 90	Average Score: 3.71	Score: 6.06 	Max Score: 6.06
# Episode 91	Average Score: 3.74	Score: 6.73 	Max Score: 6.73
# Episode 92	Average Score: 3.77	Score: 6.79 	Max Score: 6.79
# Episode 93	Average Score: 3.81	Score: 6.79 	Max Score: 6.79
# Episode 94	Average Score: 3.85	Score: 7.50 	Max Score: 7.50
# Episode 95	Average Score: 3.88	Score: 7.50 	Max Score: 7.50
# Episode 96	Average Score: 3.92	Score: 7.50 	Max Score: 7.50
# Episode 97	Average Score: 3.96	Score: 7.97 	Max Score: 7.97
# Episode 98	Average Score: 4.02	Score: 9.04 	Max Score: 9.04
# Episode 99	Average Score: 4.07	Score: 9.04 	Max Score: 9.04
# Episode 100	Average Score: 4.12	Score: 9.04 	Max Score: 9.04
# episodes: 100	avg: 4.12
# Episode 101	Average Score: 4.21	Score: 9.04 	Max Score: 9.04
# Episode 102	Average Score: 4.30	Score: 9.04 	Max Score: 9.04
# Episode 103	Average Score: 4.39	Score: 9.04 	Max Score: 9.04
# Episode 104	Average Score: 4.48	Score: 9.75 	Max Score: 9.75
# Episode 105	Average Score: 4.58	Score: 9.75 	Max Score: 9.75
# Episode 106	Average Score: 4.69	Score: 10.48 	Max Score: 10.48
# Episode 107	Average Score: 4.79	Score: 10.48 	Max Score: 10.48
# Episode 108	Average Score: 4.90	Score: 10.48 	Max Score: 10.48
# Episode 109	Average Score: 5.00	Score: 10.48 	Max Score: 10.48
# Episode 110	Average Score: 5.10	Score: 10.48 	Max Score: 10.48
# Episode 111	Average Score: 5.20	Score: 10.48 	Max Score: 10.48
# Episode 112	Average Score: 5.31	Score: 10.68 	Max Score: 10.68
# Episode 113	Average Score: 5.42	Score: 11.61 	Max Score: 11.61
# Episode 114	Average Score: 5.52	Score: 11.61 	Max Score: 11.61
# Episode 115	Average Score: 5.62	Score: 11.61 	Max Score: 11.61
# Episode 116	Average Score: 5.72	Score: 11.78 	Max Score: 11.78
# Episode 117	Average Score: 5.81	Score: 11.78 	Max Score: 11.78
# Episode 118	Average Score: 5.91	Score: 11.79 	Max Score: 11.79
# Episode 119	Average Score: 6.00	Score: 11.79 	Max Score: 11.79
# Episode 120	Average Score: 6.09	Score: 11.79 	Max Score: 11.79
# Episode 121	Average Score: 6.18	Score: 11.97 	Max Score: 11.97
# Episode 122	Average Score: 6.27	Score: 12.08 	Max Score: 12.08
# Episode 123	Average Score: 6.36	Score: 12.08 	Max Score: 12.08
# Episode 124	Average Score: 6.45	Score: 12.57 	Max Score: 12.57
# Episode 125	Average Score: 6.54	Score: 12.94 	Max Score: 12.94
# Episode 126	Average Score: 6.64	Score: 12.94 	Max Score: 12.94
# Episode 127	Average Score: 6.73	Score: 13.05 	Max Score: 13.05
# Episode 128	Average Score: 6.83	Score: 13.46 	Max Score: 13.46
# Episode 129	Average Score: 6.93	Score: 13.46 	Max Score: 13.46
# Episode 130	Average Score: 7.03	Score: 13.89 	Max Score: 13.89
# Episode 131	Average Score: 7.13	Score: 13.89 	Max Score: 13.89
# Episode 132	Average Score: 7.22	Score: 13.89 	Max Score: 13.89
# Episode 133	Average Score: 7.32	Score: 13.89 	Max Score: 13.89
# Episode 134	Average Score: 7.42	Score: 13.89 	Max Score: 13.89
# Episode 135	Average Score: 7.51	Score: 13.89 	Max Score: 13.89
# Episode 136	Average Score: 7.60	Score: 13.89 	Max Score: 13.89
# Episode 137	Average Score: 7.71	Score: 14.86 	Max Score: 14.86
# Episode 138	Average Score: 7.81	Score: 14.86 	Max Score: 14.86
# Episode 139	Average Score: 7.92	Score: 15.11 	Max Score: 15.11
# Episode 140	Average Score: 8.03	Score: 15.23 	Max Score: 15.23
# Episode 141	Average Score: 8.14	Score: 15.23 	Max Score: 15.23
# Episode 142	Average Score: 8.25	Score: 15.68 	Max Score: 15.68
# Episode 143	Average Score: 8.37	Score: 16.86 	Max Score: 16.86
# Episode 144	Average Score: 8.49	Score: 16.86 	Max Score: 16.86
# Episode 145	Average Score: 8.62	Score: 16.86 	Max Score: 16.86
# Episode 146	Average Score: 8.74	Score: 17.10 	Max Score: 17.10
# Episode 147	Average Score: 8.87	Score: 17.10 	Max Score: 17.10
# Episode 148	Average Score: 8.99	Score: 17.40 	Max Score: 17.40
# Episode 149	Average Score: 9.12	Score: 17.54 	Max Score: 17.54
# Episode 150	Average Score: 9.25	Score: 17.54 	Max Score: 17.54
# episodes: 150	avg: 9.25
# Episode 151	Average Score: 9.38	Score: 17.71 	Max Score: 17.71
# Episode 152	Average Score: 9.51	Score: 17.76 	Max Score: 17.76
# Episode 153	Average Score: 9.64	Score: 17.76 	Max Score: 17.76
# Episode 154	Average Score: 9.77	Score: 18.06 	Max Score: 18.06
# Episode 155	Average Score: 9.91	Score: 18.36 	Max Score: 18.36
# Episode 156	Average Score: 10.05	Score: 18.36 	Max Score: 18.36
# Episode 157	Average Score: 10.19	Score: 18.83 	Max Score: 18.83
# Episode 158	Average Score: 10.34	Score: 19.53 	Max Score: 19.53
# Episode 159	Average Score: 10.49	Score: 19.53 	Max Score: 19.53
# Episode 160	Average Score: 10.64	Score: 19.94 	Max Score: 19.94
# Episode 161	Average Score: 10.79	Score: 19.99 	Max Score: 19.99
# Episode 162	Average Score: 10.95	Score: 19.99 	Max Score: 19.99
# Episode 163	Average Score: 11.11	Score: 20.77 	Max Score: 20.77
# Episode 164	Average Score: 11.27	Score: 21.35 	Max Score: 21.35
# Episode 165	Average Score: 11.44	Score: 21.35 	Max Score: 21.35
# Episode 166	Average Score: 11.61	Score: 21.63 	Max Score: 21.63
# Episode 167	Average Score: 11.78	Score: 22.10 	Max Score: 22.10
# Episode 168	Average Score: 11.95	Score: 22.10 	Max Score: 22.10
# Episode 169	Average Score: 12.13	Score: 22.56 	Max Score: 22.56
# Episode 170	Average Score: 12.32	Score: 23.91 	Max Score: 23.91
# Episode 171	Average Score: 12.51	Score: 23.95 	Max Score: 23.95
# Episode 172	Average Score: 12.71	Score: 24.66 	Max Score: 24.66
# Episode 173	Average Score: 12.91	Score: 24.71 	Max Score: 24.71
# Episode 174	Average Score: 13.11	Score: 24.71 	Max Score: 24.71
# Episode 175	Average Score: 13.31	Score: 24.71 	Max Score: 24.71
# Episode 176	Average Score: 13.52	Score: 25.45 	Max Score: 25.45
# Episode 177	Average Score: 13.72	Score: 25.45 	Max Score: 25.45
# Episode 178	Average Score: 13.93	Score: 25.48 	Max Score: 25.48
# Episode 179	Average Score: 14.14	Score: 25.48 	Max Score: 25.48
# Episode 180	Average Score: 14.34	Score: 25.48 	Max Score: 25.48
# Episode 181	Average Score: 14.56	Score: 25.95 	Max Score: 25.95
# Episode 182	Average Score: 14.77	Score: 26.20 	Max Score: 26.20
# Episode 183	Average Score: 14.98	Score: 26.20 	Max Score: 26.20
# Episode 184	Average Score: 15.20	Score: 26.33 	Max Score: 26.33
# Episode 185	Average Score: 15.42	Score: 27.24 	Max Score: 27.24
# Episode 186	Average Score: 15.65	Score: 27.24 	Max Score: 27.24
# Episode 187	Average Score: 15.88	Score: 27.98 	Max Score: 27.98
# Episode 188	Average Score: 16.11	Score: 28.35 	Max Score: 28.35
# Episode 189	Average Score: 16.33	Score: 28.35 	Max Score: 28.35
# Episode 190	Average Score: 16.56	Score: 28.40 	Max Score: 28.40
# Episode 191	Average Score: 16.78	Score: 28.69 	Max Score: 28.69
# Episode 192	Average Score: 17.00	Score: 28.69 	Max Score: 28.69
# Episode 193	Average Score: 17.22	Score: 29.55 	Max Score: 29.55
# Episode 194	Average Score: 17.45	Score: 29.89 	Max Score: 29.89
# Episode 195	Average Score: 17.67	Score: 29.89 	Max Score: 29.89
# Episode 196	Average Score: 17.90	Score: 30.14 	Max Score: 30.14
# Episode 197	Average Score: 18.14	Score: 31.68 	Max Score: 31.68
# Episode 198	Average Score: 18.36	Score: 31.68 	Max Score: 31.68
# Episode 199	Average Score: 18.60	Score: 32.90 	Max Score: 32.90
# Episode 200	Average Score: 18.84	Score: 32.90 	Max Score: 32.90
# episodes: 200	avg: 18.84
# Episode 201	Average Score: 19.08	Score: 32.90 	Max Score: 32.90
# Episode 202	Average Score: 19.32	Score: 33.62 	Max Score: 33.62
# Episode 203	Average Score: 19.57	Score: 33.94 	Max Score: 33.94
# Episode 204	Average Score: 19.81	Score: 33.94 	Max Score: 33.94
# Episode 205	Average Score: 20.06	Score: 34.44 	Max Score: 34.44
# Episode 206	Average Score: 20.30	Score: 34.87 	Max Score: 34.87
# Episode 207	Average Score: 20.55	Score: 34.87 	Max Score: 34.87
# Episode 208	Average Score: 20.80	Score: 35.35 	Max Score: 35.35
# Episode 209	Average Score: 21.05	Score: 35.88 	Max Score: 35.88
# Episode 210	Average Score: 21.31	Score: 35.88 	Max Score: 35.88
# Episode 211	Average Score: 21.56	Score: 35.88 	Max Score: 35.88
# Episode 212	Average Score: 21.81	Score: 35.88 	Max Score: 35.88
# Episode 213	Average Score: 22.05	Score: 35.88 	Max Score: 35.88
# Episode 214	Average Score: 22.30	Score: 36.40 	Max Score: 36.40
# Episode 215	Average Score: 22.56	Score: 37.22 	Max Score: 37.22
# Episode 216	Average Score: 22.81	Score: 37.22 	Max Score: 37.22
# Episode 217	Average Score: 23.07	Score: 37.73 	Max Score: 37.73
# Episode 218	Average Score: 23.34	Score: 38.85 	Max Score: 38.85
# Episode 219	Average Score: 23.61	Score: 38.85 	Max Score: 38.85
# Episode 220	Average Score: 23.88	Score: 38.85 	Max Score: 38.85
# Episode 221	Average Score: 24.16	Score: 39.55 	Max Score: 39.55
# Episode 222	Average Score: 24.43	Score: 39.55 	Max Score: 39.55
# Episode 223	Average Score: 24.71	Score: 39.66 	Max Score: 39.66
# Episode 224	Average Score: 24.98	Score: 39.89 	Max Score: 39.89
# Episode 225	Average Score: 25.25	Score: 39.89 	Max Score: 39.89
# Episode 226	Average Score: 25.53	Score: 40.70 	Max Score: 40.70
# Episode 227	Average Score: 25.82	Score: 41.53 	Max Score: 41.53
# Episode 228	Average Score: 26.10	Score: 41.53 	Max Score: 41.53
# Episode 229	Average Score: 26.38	Score: 41.91 	Max Score: 41.91
# Episode 230	Average Score: 26.66	Score: 41.91 	Max Score: 41.91
# Episode 231	Average Score: 26.94	Score: 41.91 	Max Score: 41.91
# Episode 232	Average Score: 27.22	Score: 42.01 	Max Score: 42.01
# Episode 233	Average Score: 27.51	Score: 42.21 	Max Score: 42.21
# Episode 234	Average Score: 27.79	Score: 42.21 	Max Score: 42.21
# Episode 235	Average Score: 28.08	Score: 42.75 	Max Score: 42.75
# Episode 236	Average Score: 28.37	Score: 43.24 	Max Score: 43.24
# Episode 237	Average Score: 28.65	Score: 43.24 	Max Score: 43.24
# Episode 238	Average Score: 28.94	Score: 43.41 	Max Score: 43.41
# Episode 239	Average Score: 29.22	Score: 43.41 	Max Score: 43.41
# Episode 240	Average Score: 29.50	Score: 43.41 	Max Score: 43.41
# Episode 241	Average Score: 29.80	Score: 44.66 	Max Score: 44.66
# Episode 242	Average Score: 30.09	Score: 45.09 	Max Score: 45.09
# env __solved__ @ i_episode=242, w/ avg_score=30.09
# Episode 243	Average Score: 30.38	Score: 45.09 	Max Score: 45.09
# Episode 244	Average Score: 30.67	Score: 46.40 	Max Score: 46.40
# Episode 245	Average Score: 30.98	Score: 48.09 	Max Score: 48.09
# Episode 246	Average Score: 31.29	Score: 48.09 	Max Score: 48.09
# Episode 247	Average Score: 31.61	Score: 48.75 	Max Score: 48.75
# Episode 248	Average Score: 31.94	Score: 50.21 	Max Score: 50.21
# Episode 249	Average Score: 32.26	Score: 50.21 	Max Score: 50.21
# Episode 250	Average Score: 32.60	Score: 51.47 	Max Score: 51.47
# episodes: 250	avg: 32.60
# Episode 251	Average Score: 32.96	Score: 53.20 	Max Score: 53.20
# Episode 252	Average Score: 33.31	Score: 53.20 	Max Score: 53.20
# Episode 253	Average Score: 33.67	Score: 53.49 	Max Score: 53.49
# Episode 254	Average Score: 34.03	Score: 54.35 	Max Score: 54.35
# Episode 255	Average Score: 34.39	Score: 54.35 	Max Score: 54.35
# Episode 256	Average Score: 34.76	Score: 55.18 	Max Score: 55.18
# Episode 257	Average Score: 35.13	Score: 56.11 	Max Score: 56.11
# Episode 258	Average Score: 35.50	Score: 56.11 	Max Score: 56.11
# Episode 259	Average Score: 35.87	Score: 56.34 	Max Score: 56.34
# Episode 260	Average Score: 36.23	Score: 56.66 	Max Score: 56.66
# Episode 261	Average Score: 36.60	Score: 56.66 	Max Score: 56.66
# Episode 262	Average Score: 36.97	Score: 56.78 	Max Score: 56.78
# Episode 263	Average Score: 37.33	Score: 57.06 	Max Score: 57.06
# Episode 264	Average Score: 37.69	Score: 57.06 	Max Score: 57.06
# Episode 265	Average Score: 38.05	Score: 57.52 	Max Score: 57.52
# Episode 266	Average Score: 38.42	Score: 58.81 	Max Score: 58.81
# Episode 267	Average Score: 38.79	Score: 58.81 	Max Score: 58.81
# Episode 268	Average Score: 39.16	Score: 59.14 	Max Score: 59.14
# Episode 269	Average Score: 39.53	Score: 59.24 	Max Score: 59.24
# Episode 270	Average Score: 39.88	Score: 59.24 	Max Score: 59.24
# Episode 271	Average Score: 40.24	Score: 59.88 	Max Score: 59.88
# Episode 272	Average Score: 40.60	Score: 60.70 	Max Score: 60.70
# Episode 273	Average Score: 40.96	Score: 60.70 	Max Score: 60.70
# Episode 274	Average Score: 41.33	Score: 61.81 	Max Score: 61.81
# Episode 275	Average Score: 41.70	Score: 61.81 	Max Score: 61.81
# Episode 276	Average Score: 42.07	Score: 61.81 	Max Score: 61.81
# Episode 277	Average Score: 42.43	Score: 62.12 	Max Score: 62.12
# Episode 278	Average Score: 42.81	Score: 63.07 	Max Score: 63.07
# Episode 279	Average Score: 43.18	Score: 63.07 	Max Score: 63.07
# Episode 280	Average Score: 43.56	Score: 63.22 	Max Score: 63.22
# Episode 281	Average Score: 43.94	Score: 64.25 	Max Score: 64.25
# Episode 282	Average Score: 44.33	Score: 64.25 	Max Score: 64.25
# Episode 283	Average Score: 44.71	Score: 64.25 	Max Score: 64.25
# Episode 284	Average Score: 45.09	Score: 64.26 	Max Score: 64.26
# Episode 285	Average Score: 45.46	Score: 64.26 	Max Score: 64.26
# Episode 286	Average Score: 45.83	Score: 64.26 	Max Score: 64.26
# Episode 287	Average Score: 46.19	Score: 64.26 	Max Score: 64.26
# Episode 288	Average Score: 46.55	Score: 64.26 	Max Score: 64.26
# Episode 289	Average Score: 46.91	Score: 64.36 	Max Score: 64.36
# Episode 290	Average Score: 47.27	Score: 64.36 	Max Score: 64.36
# Episode 291	Average Score: 47.62	Score: 64.36 	Max Score: 64.36
# Episode 292	Average Score: 47.98	Score: 64.36 	Max Score: 64.36
# Episode 293	Average Score: 48.33	Score: 64.36 	Max Score: 64.36
# Episode 294	Average Score: 48.67	Score: 64.36 	Max Score: 64.36
# Episode 295	Average Score: 49.02	Score: 64.56 	Max Score: 64.56
# Episode 296	Average Score: 49.37	Score: 65.10 	Max Score: 65.10
# Episode 297	Average Score: 49.70	Score: 65.10 	Max Score: 65.10
# Episode 298	Average Score: 50.04	Score: 65.39 	Max Score: 65.39
# Episode 299	Average Score: 50.37	Score: 65.39 	Max Score: 65.39
# Episode 300	Average Score: 50.69	Score: 65.39 	Max Score: 65.39
# episodes: 300	avg: 50.69
# Episode 301	Average Score: 51.02	Score: 65.39 	Max Score: 65.39
# Episode 302	Average Score: 51.34	Score: 65.81 	Max Score: 65.81
# Episode 303	Average Score: 51.66	Score: 65.81 	Max Score: 65.81
# Episode 304	Average Score: 51.98	Score: 66.44 	Max Score: 66.44
# Episode 305	Average Score: 52.31	Score: 67.28 	Max Score: 67.28
# Episode 306	Average Score: 52.63	Score: 67.28 	Max Score: 67.28
# Episode 307	Average Score: 52.97	Score: 68.36 	Max Score: 68.36
# Episode 308	Average Score: 53.30	Score: 68.36 	Max Score: 68.36
# Episode 309	Average Score: 53.62	Score: 68.36 	Max Score: 68.36
# Episode 310	Average Score: 53.95	Score: 68.58 	Max Score: 68.58
# Episode 311	Average Score: 54.29	Score: 69.63 	Max Score: 69.63
# Episode 312	Average Score: 54.63	Score: 69.63 	Max Score: 69.63
# Episode 313	Average Score: 54.96	Score: 69.63 	Max Score: 69.63
# Episode 314	Average Score: 55.30	Score: 69.79 	Max Score: 69.79
# Episode 315	Average Score: 55.62	Score: 69.79 	Max Score: 69.79
# Episode 316	Average Score: 55.95	Score: 69.79 	Max Score: 69.79
# Episode 317	Average Score: 56.27	Score: 70.07 	Max Score: 70.07
# Episode 318	Average Score: 56.58	Score: 70.07 	Max Score: 70.07
# Episode 319	Average Score: 56.90	Score: 70.23 	Max Score: 70.23
# Episode 320	Average Score: 57.22	Score: 70.70 	Max Score: 70.70
# Episode 321	Average Score: 57.53	Score: 70.70 	Max Score: 70.70
# Episode 322	Average Score: 57.84	Score: 70.99 	Max Score: 70.99
# Episode 323	Average Score: 58.17	Score: 72.25 	Max Score: 72.25
# Episode 324	Average Score: 58.49	Score: 72.25 	Max Score: 72.25
# Episode 325	Average Score: 58.82	Score: 72.83 	Max Score: 72.83
# Episode 326	Average Score: 59.14	Score: 72.89 	Max Score: 72.89
# Episode 327	Average Score: 59.46	Score: 72.89 	Max Score: 72.89
# Episode 328	Average Score: 59.78	Score: 73.50 	Max Score: 73.50
# Episode 329	Average Score: 60.09	Score: 73.50 	Max Score: 73.50
# Episode 330	Average Score: 60.41	Score: 73.50 	Max Score: 73.50
# Episode 331	Average Score: 60.73	Score: 73.71 	Max Score: 73.71
# Episode 332	Average Score: 61.05	Score: 74.13 	Max Score: 74.13
# Episode 333	Average Score: 61.37	Score: 74.13 	Max Score: 74.13
# Episode 334	Average Score: 61.69	Score: 74.34 	Max Score: 74.34
# Episode 335	Average Score: 62.01	Score: 75.08 	Max Score: 75.08
# Episode 336	Average Score: 62.33	Score: 75.08 	Max Score: 75.08
# Episode 337	Average Score: 62.65	Score: 75.08 	Max Score: 75.08
# Episode 338	Average Score: 62.97	Score: 75.22 	Max Score: 75.22
# Episode 339	Average Score: 63.28	Score: 75.22 	Max Score: 75.22
# Episode 340	Average Score: 63.60	Score: 75.31 	Max Score: 75.31
# Episode 341	Average Score: 63.91	Score: 75.62 	Max Score: 75.62
# Episode 342	Average Score: 64.22	Score: 75.62 	Max Score: 75.62
# Episode 343	Average Score: 64.53	Score: 76.58 	Max Score: 76.58
# Episode 344	Average Score: 64.84	Score: 76.69 	Max Score: 76.69
# Episode 345	Average Score: 65.12	Score: 76.69 	Max Score: 76.69
# Episode 346	Average Score: 65.41	Score: 77.15 	Max Score: 77.15
# Episode 347	Average Score: 65.71	Score: 78.36 	Max Score: 78.36
# Episode 348	Average Score: 65.99	Score: 78.36 	Max Score: 78.36
# Episode 349	Average Score: 66.27	Score: 78.59 	Max Score: 78.59
# Episode 350	Average Score: 66.54	Score: 78.59 	Max Score: 78.59
# episodes: 350	avg: 66.54
# Episode 351	Average Score: 66.80	Score: 78.59 	Max Score: 78.59
# Episode 352	Average Score: 67.07	Score: 79.94 	Max Score: 79.94
# Episode 353	Average Score: 67.34	Score: 80.51 	Max Score: 80.51
# Episode 354	Average Score: 67.60	Score: 80.51 	Max Score: 80.51
# Episode 355	Average Score: 67.86	Score: 80.75 	Max Score: 80.75
# Episode 356	Average Score: 68.13	Score: 82.38 	Max Score: 82.38
# Episode 357	Average Score: 68.40	Score: 82.38 	Max Score: 82.38
# Episode 358	Average Score: 68.66	Score: 82.50 	Max Score: 82.50
# Episode 359	Average Score: 68.93	Score: 83.15 	Max Score: 83.15
# Episode 360	Average Score: 69.19	Score: 83.15 	Max Score: 83.15
# Episode 361	Average Score: 69.46	Score: 83.27 	Max Score: 83.27
# Episode 362	Average Score: 69.72	Score: 83.31 	Max Score: 83.31
# Episode 363	Average Score: 69.99	Score: 83.31 	Max Score: 83.31
# Episode 364	Average Score: 70.26	Score: 83.86 	Max Score: 83.86
# Episode 365	Average Score: 70.52	Score: 84.38 	Max Score: 84.38
# Episode 366	Average Score: 70.78	Score: 84.38 	Max Score: 84.38
# Episode 367	Average Score: 71.04	Score: 84.50 	Max Score: 84.50
# Episode 368	Average Score: 71.29	Score: 84.73 	Max Score: 84.73
# Episode 369	Average Score: 71.55	Score: 84.73 	Max Score: 84.73
# Episode 370	Average Score: 71.80	Score: 84.84 	Max Score: 84.84
# Episode 371	Average Score: 72.05	Score: 84.91 	Max Score: 84.91
# Episode 372	Average Score: 72.30	Score: 84.91 	Max Score: 84.91
# Episode 373	Average Score: 72.54	Score: 85.01 	Max Score: 85.01
# Episode 374	Average Score: 72.77	Score: 85.35 	Max Score: 85.35
# Episode 375	Average Score: 73.01	Score: 85.35 	Max Score: 85.35
# Episode 376	Average Score: 73.25	Score: 85.35 	Max Score: 85.35
# Episode 377	Average Score: 73.48	Score: 85.71 	Max Score: 85.71
# Episode 378	Average Score: 73.71	Score: 85.71 	Max Score: 85.71
# Episode 379	Average Score: 73.94	Score: 86.15 	Max Score: 86.15
# Episode 380	Average Score: 74.17	Score: 86.15 	Max Score: 86.15
# Episode 381	Average Score: 74.39	Score: 86.15 	Max Score: 86.15
# Episode 382	Average Score: 74.61	Score: 86.60 	Max Score: 86.60
# Episode 383	Average Score: 74.83	Score: 86.60 	Max Score: 86.60
# Episode 384	Average Score: 75.06	Score: 86.60 	Max Score: 86.60
# Episode 385	Average Score: 75.29	Score: 87.10 	Max Score: 87.10
# Episode 386	Average Score: 75.52	Score: 87.24 	Max Score: 87.24
# Episode 387	Average Score: 75.74	Score: 87.24 	Max Score: 87.24
# Episode 388	Average Score: 75.97	Score: 87.24 	Max Score: 87.24
# Episode 389	Average Score: 76.20	Score: 87.30 	Max Score: 87.30
# Episode 390	Average Score: 76.43	Score: 87.30 	Max Score: 87.30
# Episode 391	Average Score: 76.66	Score: 87.30 	Max Score: 87.30
# Episode 392	Average Score: 76.89	Score: 87.30 	Max Score: 87.30
# Episode 393	Average Score: 77.12	Score: 87.30 	Max Score: 87.30
# Episode 394	Average Score: 77.35	Score: 87.30 	Max Score: 87.30
# Episode 395	Average Score: 77.58	Score: 87.30 	Max Score: 87.30
# Episode 396	Average Score: 77.80	Score: 87.30 	Max Score: 87.30
# Episode 397	Average Score: 78.02	Score: 87.37 	Max Score: 87.37
# Episode 398	Average Score: 78.24	Score: 87.37 	Max Score: 87.37
# Episode 399	Average Score: 78.46	Score: 87.37 	Max Score: 87.37
# Episode 400	Average Score: 78.68	Score: 87.37 	Max Score: 87.37
# episodes: 400	avg: 78.68

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episodes')
plt.show()

# %%
env.close()
